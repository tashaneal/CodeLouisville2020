# %%
import pandas as pd
import sqlite3
import os
os.getcwd()

#create the sqlite DB
db = sqlite3.connect ("MyDemo.db")

#read CSV into dataframe
df1 = pd.read_csv ("titanic.csv", header=None)

#convert the pandas dataframe to a sqlite table
df1.to_sql("Survived",db, if_exists="replace")

def run_query (query):
    return pd.read_sql_query(query,db)

os.getcwd()
# Out:
# 'C:\\Users\\admin\\Documents\\PythonForDataAnalysis'

# %%
#view dataframe
df1
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
query = """
SELECT *
FROM sqlite_master
ORDER BY name;
"""
run_query(query)
# Out:
#     type                            name                tbl_name  rootpage  \
# 0  table                        Survived                Survived         6
# 1  index               ix_Survived_index                Survived         3
# 2  index  ix_stage_expenses_import_index   stage_expenses_import         4
# 3  table          stage_expenses_cleaned  stage_expenses_cleaned         5
# 4  table           stage_expenses_import   stage_expenses_import         2
#
#                                                  sql
# 0  CREATE TABLE "Survived" (\n"index" INTEGER,\n ...
# 1  CREATE INDEX "ix_Survived_index"ON "Survived" ...
# 2  CREATE INDEX "ix_stage_expenses_import_index"O...
# 3  CREATE TABLE stage_expenses_cleaned(\n  Tran_D...
# 4  CREATE TABLE "stage_expenses_import" (\n"index...

# %%
query = """
SELECT *
FROM Survived;
"""
run_query(query)
# Out:
#      index            0         1       2  \
# 0        0  PassengerId  Survived  Pclass
# 1        1            1         0       3
# 2        2            2         1       1
# 3        3            3         1       3
# 4        4            4         1       1
# ..     ...          ...       ...     ...
# 887    887          887         0       2
# 888    888          888         1       1
# 889    889          889         0       3
# 890    890          890         1       1
# 891    891          891         0       3
#
#                                                      3       4     5      6  \
# 0                                                 Name     Sex   Age  SibSp
# 1                              Braund, Mr. Owen Harris    male    22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38      1
# 3                               Heikkinen, Miss. Laina  female    26      0
# ...

# %%
# WINDOWS absolute path - read CSV into dataframe
#df1 = pd.read_csv(r"C:\Users\admin\Downloads\titanic.csv (1)\titanic.csv")
df1 = pd.read_csv("titanic.csv")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## view results

df1.head(10)
#df4.tail(2)
#df4.sample(5)
#df4[["my_datetime", "source"]]

##series
#df4['user_id']

#df4[df4.source == 'Reddit']
#df4.sample(100)

#df4[['source']].count()
#df4[['source']].sum()
#df4[['user_id']].sum()

#df1
#df3
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...
